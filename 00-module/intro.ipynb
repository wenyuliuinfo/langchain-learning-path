# %% [markdown]
# # LangChain Academy
#
# ## Context
# One type of LLM application you can build is an agent. There's a lot of excitement around building agents because they can automate a wide range of tasks that were previously impossible.
#
# In practice, it is incredibly difficult to build systems that reliably execute on these tasks. As we've worked with our users to put agents into production, we've learned that more control is often necessary. You might need an agent to always call a specific tool first or use different prompts based on its state.
#
# To tackle this, we've built LangGraph - a framework for building agent and multi-agent applications. Separate from the LangChain package, LangGraph core design philosophy is to help developers add better precision and control into agent frameworks, suitable for the complexity of real-world systems.
#
# ## Chat Models
# In this course, we will use Chat Models, which take a sequence of messages as input and return messages as output. LangChain supports many models via third-party integration.

# %%
# Import libraries
import os
from dotenv import load_dotenv
from serpapi import GoogleSearch
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

# Load env variable for API Key
load_dotenv()
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")
SERP_API_KEY = os.getenv("SERP_API_KEY")

# %% [markdown]
# There are a few standard parameters that we can set with chat models. Two of the most common are:
# - `model`: the name of the model.
# - `temperature`: the sampling temperature.
#
# `Temperature` controls the randomness or creativity of the model's output where low temperature is more deterministic and focused outputs. This is good for tasks requiring accuracy or factual responses. High temperature is good for creative tasks or generating varied responses.

# %%
# Set the Chat Model
deepseek_chat = ChatOpenAI(
    model="deepseek-v4-pro",  # Or "deepseek-v4-flash" for a faster option
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    temperature=0
)

# %% [markdown]
# Chat Model in LangChain have a number of default methods. For the most part, we'll be using:
# - stream: stream back chunks of the response.
# - invoke: call the chain on an input.
#
# And chat models take messages as input. Messages have a role and content property. We'll be talking a lot more about this later.

# %%
# Create a message
msg = HumanMessage(content="Hello World", name="Lance")
messages = [msg]

# Invoke the model with a list of messages
deepseek_chat.invoke(messages)
deepseek_chat.invoke("Hello world")
# Out:
# AIMessage(content='Hello, World! 🌍\n\nIf you\'d like to see "Hello, World!" in a specific programming language, just let me know!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 118, 'prompt_tokens': 6, 'total_tokens': 124, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 88, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 6}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-pro', 'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402', 'id': 'aed79b86-8489-486b-8fc9-7edd73c70515', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4633-9f62-7981-a276-9181ecbb96a1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 118, 'total_tokens': 124, 'input_token_details': {'cache_read': 0}, 'output_token_de
# ...

# %% [markdown]
# We get an `AIMessage` response. Also, note that we can just invoke a chat model with a string. When a string is passed as input, it is converted to a `HumanMessage` and then passed to the underlying model.
#
# The interface is consistent across all chat models and models are typically initialized once at the start up each notebooks.
#
# ## Search Tools
# Search tools can be used for LLMs.

# %%
params = {
        "q": "What is LangGraph?",
        "location": "China",
        "hl": "en",
        "gl": "cn",
        "api_key": SERP_API_KEY
    }

# Create the search object and execute it
search = GoogleSearch(params)
results = search.get_dict()
print(results)
# Out:
# {'search_metadata': {'id': '6a4f696973d224e32eb04c60', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/kOGGS6QS_TwaEflI8i5JMQ/6a4f696973d224e32eb04c60.json', 'pixel_position_endpoint': 'https://serpapi.com/searches/kOGGS6QS_TwaEflI8i5JMQ/6a4f696973d224e32eb04c60.json_with_pixel_position', 'created_at': '2026-07-09 09:27:05 UTC', 'processed_at': '2026-07-09 09:27:05 UTC', 'google_url': 'https://www.google.com/search?q=What+is+LangGraph%3F&oq=What+is+LangGraph%3F&uule=w+CAIQICIFQ2hpbmE&hl=en&gl=cn&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/kOGGS6QS_TwaEflI8i5JMQ/6a4f696973d224e32eb04c60.html', 'total_time_taken': 1.18}, 'search_parameters': {'engine': 'google', 'q': 'What is LangGraph?', 'location_requested': 'China', 'location_used': 'China', 'google_domain': 'google.com', 'hl': 'en', 'gl': 'cn', 'device': 'desktop'}, 'search_information': {'query_displayed': 'What is LangGraph?', 'total_results': 47, 'time_taken_displayed': 0.19, 'or
# ...
